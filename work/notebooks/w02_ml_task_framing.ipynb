# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MaryamHasnat/FLYRANK_AI/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
   # !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
   # %cd flyrank-ml-internship-starter
# Out:
# fatal: destination path 'flyrank-ml-internship-starter' already exists and is not an empty directory.
# /content/flyrank-ml-internship-starter

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
#    This lane is a ranking/scoring problem: "which content should an editor fix first" maps to producing a priority score, not a yes/no label.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target proxy: trend_direction == 'down' (or trend_pct for a finer score). This is observed from real 90-day history, not a hand-defined rule — and it's never used as a feature, only as the outcome being predicted.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success metric: precision@K — of the top K items ranked as highest priority, what fraction are actually declining.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv('data/raw/content_refresh_anonymized.csv')

# unit of analysis: one row per content item
print(df[['content_id', 'client_id']].head())
print("\nUnique content items:", df['content_id'].nunique())

# sketch the target
df['is_down'] = df['trend_direction'] == 'down'
print("\nTarget sketch (is_down):")
print(df[['content_id', 'trend_direction', 'trend_pct', 'is_down']].head(10))
# Out:
#              content_id          client_id
# 0  content_304f48230142  client_f369cb89fc
# 1  content_a1fb4e703a9e  client_4e07408562
# 2  content_9aa793d4d895  client_7f2253d7e2
# 3  content_331d6c4de07b  client_19581e27de
# 4  content_d99b7a2d90ca  client_3fdba35f04
#
# Unique content items: 30000
#
# Target sketch (is_down):
#              content_id trend_direction  trend_pct  is_down
# 0  content_304f48230142            down      -41.4     True
# 1  content_a1fb4e703a9e            down      -57.7     True
# 2  content_9aa793d4d895            down      -60.9     True
# 3  content_331d6c4de07b          stable      -13.8    False
# 4  content_d99b7a2d90ca            down      -34.7     True
# 5  content_d4084a4bc775            down      -38.9     True
# 6  content_9a34b442b552            down      -92.3     True
# 7  content_a63219c6e95a          stable        0.6    False
# 8  content_5e6c160719bc            down      -58.8     True
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A rule like "flag low position" misses this: declining content averages better position (15.9) than stable content (18.4), but less than half the CTR (0.32% vs 0.73%). Decline comes from a tangle of signals, not one threshold — where a learned model earns its place over FlyRank's existing flags.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
